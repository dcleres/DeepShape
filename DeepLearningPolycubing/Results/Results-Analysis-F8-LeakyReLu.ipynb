# %%
import matplotlib
#matplotlib.use("nbagg")

import matplotlib.pyplot as plt
import numpy as np
#from mpl_toolkits.mplot3d import Axes3D

from os import listdir
from os.path import isfile, join
import numpy as np
import math

# %% [markdown]
# # Upload Data

# %%
#TRAINING
#training_accuracy_Adam_softmax = np.load('/Users/davidcleres/DeepShape/DeepLearningPolycubing/Results/F8/training_accuracy_Adam_softmax.npy')
training_accuracy_Adamax_softmax = np.load('/Users/davidcleres/DeepShape/DeepLearningPolycubing/Results/F8/training_accuracy_Adamax_softmax.npy')
training_accuracy_SGD_softmax = np.load('/Users/davidcleres/DeepShape/DeepLearningPolycubing/Results/F8/training_accuracy_SGD_softmax.npy')
training_accuracy_RMS_softmax = np.load('/Users/davidcleres/DeepShape/DeepLearningPolycubing/Results/F8/training_accuracy_RMS_softmax.npy')

training_accuracy_Adam_sigmoid = np.load('/Users/davidcleres/DeepShape/DeepLearningPolycubing/Results/F8/training_accuracy_Adam.npy')
training_accuracy_Adamax_sigmoid = np.load('/Users/davidcleres/DeepShape/DeepLearningPolycubing/Results/F8/training_accuracy_Adamax.npy')
training_accuracy_SGD_sigmoid = np.load('/Users/davidcleres/DeepShape/DeepLearningPolycubing/Results/F8/training_accuracy_SGD.npy')
training_accuracy_RMS_sigmoid = np.load('/Users/davidcleres/DeepShape/DeepLearningPolycubing/Results/F8/training_accuracy_RMS.npy')

#VALIDATION
#validation_accuracy_Adam_softmax = np.load('/Users/davidcleres/DeepShape/DeepLearningPolycubing/Results/F8/validation_accuracy_Adam_softmax.npy')
validation_accuracy_Adamax_softmax = np.load('/Users/davidcleres/DeepShape/DeepLearningPolycubing/Results/F8/validation_accuracy_Adamax_softmax.npy')
validation_accuracy_SGD_softmax = np.load('/Users/davidcleres/DeepShape/DeepLearningPolycubing/Results/F8/validation_accuracy_SGD_softmax.npy')
validation_accuracy_RMS_softmax = np.load('/Users/davidcleres/DeepShape/DeepLearningPolycubing/Results/F8/validation_accuracy_RMS_softmax.npy')

validation_accuracy_Adam_sigmoid = np.load('/Users/davidcleres/DeepShape/DeepLearningPolycubing/Results/F8/validation_accuracy_Adam.npy')
validation_accuracy_Adamax_sigmoid = np.load('/Users/davidcleres/DeepShape/DeepLearningPolycubing/Results/F8/validation_accuracy_Adamax.npy')
validation_accuracy_SGD_sigmoid = np.load('/Users/davidcleres/DeepShape/DeepLearningPolycubing/Results/F8/validation_accuracy_SGD.npy')
validation_accuracy_RMS_sigmoid = np.load('/Users/davidcleres/DeepShape/DeepLearningPolycubing/Results/F8/validation_accuracy_RMS.npy')

# %%
#Raw Results 

print('training_accuracy_Adamax_softmax',training_accuracy_Adamax_softmax[-1])
print('training_accuracy_SGD_softmax', training_accuracy_SGD_softmax[-1])
print('training_accuracy_RMS_softmax', training_accuracy_RMS_softmax[-1])

print('training_accuracy_Adam_sigmoid',training_accuracy_Adam_sigmoid[-1])
print('training_accuracy_Adamax_sigmoid', training_accuracy_Adamax_sigmoid[-1]) 
print('training_accuracy_SGD_sigmoid',training_accuracy_SGD_sigmoid[-1])
print('training_accuracy_RMS_sigmoid', training_accuracy_RMS_sigmoid[-1])

#VALIDATION
#validation_accuracy_Adam_softmax = np.load('/Users/davidcleres/DeepShape/DeepLearningPolycubing/Results/F8/validation_accuracy_Adam_softmax.npy')
print(validation_accuracy_Adamax_softmax[-1])
print(validation_accuracy_SGD_softmax[-1])
print(validation_accuracy_RMS_softmax[-1])

print(validation_accuracy_Adam_sigmoid[-1])
print(validation_accuracy_Adamax_sigmoid[-1])
print(validation_accuracy_SGD_sigmoid[-1])
print(validation_accuracy_RMS_sigmoid[-1])
# Out:
# training_accuracy_Adamax_softmax 99.99627
# training_accuracy_SGD_softmax 99.98494
# training_accuracy_RMS_softmax 98.144325
# training_accuracy_Adam_sigmoid 99.98243
# training_accuracy_Adamax_sigmoid 99.984535
# training_accuracy_SGD_sigmoid 99.86213
# training_accuracy_RMS_sigmoid 99.89929
# 97.15393
# 97.79134
# 97.95614
# 97.39645
# 96.92098
# 97.309364
# 97.2406

# %% [markdown]
# # Softmax

# %%
#plt.plot(training_accuracy_Adam_softmax)
plt.plot(training_accuracy_Adamax_softmax)
plt.plot(training_accuracy_SGD_softmax)
plt.plot(training_accuracy_RMS_softmax)

#plt.plot(validation_accuracy_Adam_softmax)
plt.plot(validation_accuracy_Adamax_softmax)
plt.plot(training_accuracy_SGD_softmax)
plt.plot(validation_accuracy_RMS_softmax)

plt.legend(['training_accuracy_Adam_softmax', 'training_accuracy_Adamax_softmax', 'training_accuracy_RMS_softmax', 'validation_accuracy_Adam_softmax', 'validation_accuracy_Adamax_softmax', 'validation_accuracy_RMS_softmax'])
plt.title('Training vs. Validation Accuracy - Softmax')
plt.xlabel('Epochs')
plt.ylabel('Accuracy (in %)')
plt.show()

# %%
#plt.plot(training_accuracy_Adam_softmax)
plt.plot(training_accuracy_Adamax_softmax)
plt.plot(training_accuracy_SGD_softmax)
plt.plot(training_accuracy_RMS_softmax)

#plt.plot(validation_accuracy_Adam_softmax)
#plt.plot(validation_accuracy_Adamax_softmax)
#plt.plot(training_accuracy_SGD_softmax)
#plt.plot(validation_accuracy_RMS_softmax)

plt.legend(['training_accuracy_Adam_softmax', 'training_accuracy_Adamax_softmax', 'training_accuracy_RMS_softmax', 'validation_accuracy_Adam_softmax', 'validation_accuracy_Adamax_softmax', 'validation_accuracy_RMS_softmax'])
plt.title('Training vs. Validation Accuracy - Softmax')
plt.xlabel('Epochs')
plt.ylabel('Accuracy (in %)')
plt.show()

# %%
#plt.plot(training_accuracy_Adam_softmax)
plt.plot(training_accuracy_Adamax_softmax)
#plt.plot(training_accuracy_SGD_softmax)
#plt.plot(training_accuracy_RMS_softmax)

#plt.plot(validation_accuracy_Adam_softmax)
plt.plot(validation_accuracy_Adamax_softmax)
#plt.plot(training_accuracy_SGD_softmax)
#plt.plot(validation_accuracy_RMS_softmax)

plt.legend(['training_accuracy_Adam_softmax', 'validation_accuracy_Adam_softmax'])
plt.title('Training vs. Validation Accuracy - Softmax')
plt.xlabel('Epochs')
plt.ylabel('Accuracy (in %)')
plt.show()

# %% [markdown]
# # Sigmoid

# %%
plt.plot(training_accuracy_Adam_sigmoid)
plt.plot(training_accuracy_Adamax_sigmoid)
plt.plot(training_accuracy_SGD_sigmoid)
plt.plot(training_accuracy_RMS_sigmoid)

plt.plot(validation_accuracy_Adam_sigmoid)
plt.plot(validation_accuracy_Adamax_sigmoid)
plt.plot(validation_accuracy_SGD_sigmoid)
plt.plot(validation_accuracy_RMS_sigmoid)

plt.legend(['training_accuracy_Adam', 'training_accuracy_Adamax', 'training_accuracy_RMS', 'validation_accuracy_Adam', 'validation_accuracy_Adamax', 'validation_accuracy_RMS'])
plt.title('Training vs. Validation Accuracy - Sigmoid')
plt.xlabel('Epochs')
plt.ylabel('Accuracy (in %)')



plt.show()

# %%
plt.plot(training_accuracy_Adam_sigmoid)
plt.plot(training_accuracy_Adamax_sigmoid)
plt.plot(training_accuracy_SGD_sigmoid)
plt.plot(training_accuracy_RMS_sigmoid)

plt.legend(['training_accuracy_Adam_sigmoid', 'training_accuracy_Adamax_sigmoid', 'training_accuracy_SGD_sigmoid','training_accuracy_RMS_sigmoid'])
plt.title('Training vs. Validation Accuracy - Sigmoid')
plt.xlabel('Epochs')
plt.ylabel('Accuracy (in %)')
plt.show()
