# %%
import matplotlib
#matplotlib.use("nbagg")

import matplotlib.pyplot as plt
import numpy as np
#from mpl_toolkits.mplot3d import Axes3D

from os import listdir
from os.path import isfile, join
import numpy as np
import math

# %% [markdown]
# # Upload Data

# %%
#TRAINING
training_accuracy_Adam_sigmoid = np.load('/Users/davidcleres/DeepShape/DeepLearningPolycubing/Results/F4-Sig/training_accuracy_Adam.npy')
training_accuracy_Adamax_sigmoid = np.load('/Users/davidcleres/DeepShape/DeepLearningPolycubing/Results/F4-Sig/training_accuracy_Adamax.npy')
training_accuracy_SGD_sigmoid = np.load('/Users/davidcleres/DeepShape/DeepLearningPolycubing/Results/F4-Sig/training_accuracy_SGD.npy')
training_accuracy_RMS_sigmoid = np.load('/Users/davidcleres/DeepShape/DeepLearningPolycubing/Results/F4-Sig/training_accuracy_RMS.npy')

#VALIDATIOM
validation_accuracy_Adam_sigmoid = np.load('/Users/davidcleres/DeepShape/DeepLearningPolycubing/Results/F4-Sig/validation_accuracy_Adam.npy')
validation_accuracy_Adamax_sigmoid = np.load('/Users/davidcleres/DeepShape/DeepLearningPolycubing/Results/F4-Sig/validation_accuracy_Adamax.npy')
validation_accuracy_SGD_sigmoid = np.load('/Users/davidcleres/DeepShape/DeepLearningPolycubing/Results/F4-Sig/validation_accuracy_SGD.npy')
validation_accuracy_RMS_sigmoid = np.load('/Users/davidcleres/DeepShape/DeepLearningPolycubing/Results/F4-Sig/validation_accuracy_RMS.npy')

# %%
print('training_accuracy_Adam_sigmoid',training_accuracy_Adam_sigmoid[-1])
print('training_accuracy_Adamax_sigmoid', training_accuracy_Adamax_sigmoid[-1]) 
print('training_accuracy_SGD_sigmoid',training_accuracy_SGD_sigmoid[-1])
print('training_accuracy_RMS_sigmoid', training_accuracy_RMS_sigmoid[-1])

print('\n')

#VALIDATION
print('validation_accuracy_Adam_sigmoid',validation_accuracy_Adam_sigmoid[-1])
print('validation_accuracy_Adamax_sigmoid',validation_accuracy_Adamax_sigmoid[-1])
print('validation_accuracy_SGD_sigmoid',validation_accuracy_SGD_sigmoid[-1])
print('validation_accuracy_RMS_sigmoid',validation_accuracy_RMS_sigmoid[-1])
# Out:
# training_accuracy_Adam_sigmoid 99.67869
# training_accuracy_Adamax_sigmoid 97.279526
# training_accuracy_SGD_sigmoid 93.94247
# training_accuracy_RMS_sigmoid 96.2757
#
#
# validation_accuracy_Adam_sigmoid 97.12687
# validation_accuracy_Adamax_sigmoid 97.09188
# validation_accuracy_SGD_sigmoid 93.5024
# validation_accuracy_RMS_sigmoid 95.58187

# %% [markdown]
# # Sigmoid

# %%
plt.plot(training_accuracy_Adam_sigmoid)
plt.plot(training_accuracy_Adamax_sigmoid)
plt.plot(training_accuracy_SGD_sigmoid)
plt.plot(training_accuracy_RMS_sigmoid)

plt.legend(['training_accuracy_Adam_sigmoid', 'training_accuracy_Adamax_sigmoid', 'training_accuracy_SGD_sigmoid','training_accuracy_RMS_sigmoid'])
plt.title('Training vs. Validation Accuracy - Sigmoid')
plt.xlabel('Epochs')
plt.ylabel('Accuracy (in %)')
plt.show()
